# %%
import os
import cv2
import tkinter as tk
from PIL import Image, ImageTk

# --- Configuration ---
SOURCE_FOLDER = 'Annotated_Better_Again/OCRData/'  # Folder containing your PNGs
OUTPUT_FOLDER = 'Annotated_Better_Again/OCRData/OCRlabels/'  # Where the txt files will be saved

class ImageLabeler:
    def __init__(self, root):
        self.root = root
        self.root.title("Quick Labeler")
        
        # Ensure output directory exists
        if not os.path.exists(OUTPUT_FOLDER):
            os.makedirs(OUTPUT_FOLDER)

        # Get list of PNGs that don't have a label yet
        self.all_files = [f for f in os.listdir(SOURCE_FOLDER) if f.lower().endswith('.png')]
        self.files_to_label = [f for f in self.all_files if not self._label_exists(f)]
        self.current_index = 0

        if not self.files_to_label:
            print("No new images to label!")
            self.root.destroy()
            return

        # UI Elements
        self.img_label = tk.Label(root)
        self.img_label.pack(pady=10)

        self.label_var = tk.StringVar()
        self.entry = tk.Entry(root, textvariable=self.label_var, width=50)
        self.entry.pack(pady=10, padx=20)
        self.entry.bind("<Return>", self.save_and_next) # Bind Enter key
        self.entry.focus_set()

        self.status_label = tk.Label(root, text="", fg="gray")
        self.status_label.pack()

        self.load_image()

    def _label_exists(self, filename):
        txt_name = os.path.splitext(filename)[0] + ".txt"
        return os.path.exists(os.path.join(OUTPUT_FOLDER, txt_name))

    def load_image(self):
        if self.current_index < len(self.files_to_label):
            filename = self.files_to_label[self.current_index]
            path = os.path.join(SOURCE_FOLDER, filename)
            
            # Read with OpenCV, convert to RGB for Tkinter
            cv_img = cv2.imread(path)
            cv_img = cv2.cvtColor(cv_img, cv2.COLOR_BGR2RGB)
            
            # Resize image to fit screen if necessary (e.g., max 800px width)
            h, w, _ = cv_img.shape
            if w > 800:
                ratio = 800 / w
                cv_img = cv2.resize(cv_img, (800, int(h * ratio)))

            self.img_tk = ImageTk.PhotoImage(image=Image.fromarray(cv_img))
            self.img_label.config(image=self.img_tk)
            self.status_label.config(text=f"Image {self.current_index + 1}/{len(self.files_to_label)}: {filename}")
            self.label_var.set("") # Clear text box
        else:
            print("Finished labeling all images.")
            self.root.destroy()

    def save_and_next(self, event=None):
        label = self.label_var.get().strip()
        if label:
            filename = self.files_to_label[self.current_index]
            txt_name = os.path.splitext(filename)[0] + ".txt"
            save_path = os.path.join(OUTPUT_FOLDER, txt_name)

            with open(save_path, 'w') as f:
                f.write(label)
            
            print(f"Saved: {txt_name}")
            self.current_index += 1
            self.load_image()
        else:
            print("Please enter a label before hitting Enter.")

if __name__ == "__main__":
    root = tk.Tk()
    app = ImageLabeler(root)
    root.mainloop()
# Out:
# Saved: Screenshot 2026-04-01 104755.txt
# Saved: Screenshot 2026-04-01 104809.txt
# Saved: Screenshot 2026-04-01 104825.txt
# Saved: Screenshot 2026-04-01 104833.txt
# Saved: Screenshot 2026-04-01 104841.txt
# Saved: Screenshot 2026-04-01 104849.txt
# Saved: Screenshot 2026-04-01 104856.txt
# Please enter a label before hitting Enter.
# Please enter a label before hitting Enter.
# Please enter a label before hitting Enter.
# Please enter a label before hitting Enter.
# Please enter a label before hitting Enter.
# Please enter a label before hitting Enter.
# Please enter a label before hitting Enter.
# Please enter a label before hitting Enter.
# Please enter a label before hitting Enter.
# Please enter a label before hitting Enter.
# Saved: Screenshot 2026-04-01 104903.txt
# Saved: Screenshot 2026-04-01 104910.txt
# Saved: Screenshot 2026-04-01 104916.txt
# Saved: Screenshot 2026-04-01 104924.txt
# Saved: Screenshot 2026-04-01 104931.txt
# Saved: Screenshot 2026-04-01 104937.txt
# Saved: Screenshot 2026-04-01 104943.txt
# Saved: Screenshot 2026-04-01 104951.txt
# Saved: Screenshot 2026-04-01 104956.txt
# Saved: Screenshot 2026-04-01 105005.txt
# Saved: Screenshot 2026-04-01 105012.txt
# Saved: Screenshot 2026-04-01 105020.txt
# Saved: Screenshot 2026-04-01 105026.txt
# Saved: Screenshot 2026-04-01 105146.txt
# Saved: Screenshot 2026-04-01 105155.txt
# Saved: Screenshot 2026-04-01 105201.txt
# Saved: Screenshot 2026-04-01 105214.txt
# Saved: Screenshot 2026-04-01 105219.txt
# Saved: Screenshot 2026-04-01 105228.txt
# Saved: Screenshot 2026-04-01 105235.txt
# Saved: Screenshot 2026-04-01 105240.txt
# Saved: Screenshot 2026-04-01 105245.txt
# Saved: Screenshot 2026-04-01 105252.txt
# Saved: Screenshot 2026-04-01 105258.txt
# Saved: Screenshot 2026-04-01 105307.txt
# Saved: Screenshot 2026-04-01 105313.txt
# Saved: Screenshot 2026-04-01 105319.txt
# Saved: Screenshot 2026-04-01 105326.txt
# Saved: Screenshot 2026-04-01 105425.txt
# Saved: Screenshot 2026-04-01 105431.txt
# Saved: Screenshot 2026-04-01 105440.txt
# Saved: Screenshot 2026-04-01 105445.txt
# Saved: Screenshot 2026-04-01 105452.txt
# Saved: Screenshot 2026-04-01 105459.txt
# Saved: Screenshot 2026-04-01 105507.txt
# Finished labeling all images.
